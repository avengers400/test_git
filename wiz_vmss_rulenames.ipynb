# %%
import pandas as pd

# %%
df = pd.read_csv('MI_VMSS_RULES.csv')

# %%
print(df['CriteriaRules'])
# Out:
# 0       1e025bc1-ff97-409f-982d-39a810d5fa25
# 1       bdc54b11-ece6-44b4-92a6-2bd3783fd0f2
# 2                   5c8c26027a550e1fb6560be3
# 3       d19cb41d-ac6c-4e95-848a-48f0fe9a9176
# 4       3abf3147-ea53-4302-b237-caab4d764c77
#                         ...
# 1971    3861c363-849f-4c5f-a4a3-e48465e08e81
# 1972    3861c363-849f-4c5f-a4a3-e48465e08e81
# 1973    86d7328a-5d75-411d-8afb-316f8402e239
# 1974    2f9da251-dbbf-408b-954c-fdcdd902aa1e
# 1975    c71c5c06-1911-4977-a5af-bb2642fccfda
# Name: CriteriaRules, Length: 1976, dtype: object

# %%
unique_accounts = df['CriteriaCloudAccounts'].unique()

# %%
unique_rules = df['CriteriaRules'].unique()

# %%
print(unique_rules)
# Out:
# ['bdc54b11-ece6-44b4-92a6-2bd3783fd0f2'
#  'ab17b9a8-c319-40ee-9c0d-3c18293a4895' '5c8c261f7a550e1fb6560c11'
#  '5c8c26657a550e1fb6560c6c' 'db845ddf-dd7d-41bc-813d-06fffc19c12b'
#  '5c8c26167a550e1fb6560c03' '8814b7e4-551d-409a-9f9f-333af4f7d253'
#  '1d187035-9fff-48b2-a7c3-ffc56a4da5e6' '5c8c26667a550e1fb6560c6d'
#  '3abf3147-ea53-4302-b237-caab4d764c77']

# %%
print(unique_accounts)
# Out:
# ['128927813985' '299975258897' '39042342264'
#  '4ca5bab4-97a5-4ffc-80ab-da7aad20c8a2' '277141866027' '130312249203'
#  '11275511485' '608515732360' '34391304590' '947044032016' '610375267642'
#  nan '9cae53a3-58c5-45cb-b9cc-2091568ea5f4' '712241193000' '435452409739'
#  '703722312672' '198052631016' '5ed9cd7d-e925-421b-9f58-53d42ee932e3'
#  '6767f91e-2c29-4854-b348-cc128a9e4b36'
#  '60fc1293-262e-4c56-95e1-6a7f49d76c9f'
#  'c38f1b10-c6b3-4dee-a2e3-9cb4eddbea53'
#  '45af0036-4fba-4e07-b645-93ad92ba2f1d'
#  'bb838cb5-5716-49ab-8533-1ee931015247'
#  '034391304590; 435452409739; 608515732360'
#  '0954c5d1-91de-451f-986d-cf51cda718f4'
#  'dd30f094-40b1-4431-a60b-acc9fbf41ad4']

# %%
unique_rules = [
  "1e025bc1-ff97-409f-982d-39a810d5fa25",
  "bdc54b11-ece6-44b4-92a6-2bd3783fd0f2",
  "5d211f33-640f-47d5-860d-20b8c4205597",
  "86d7328a-5d75-411d-8afb-316f8402e239",
  "5c8c25f37a550e1fb6560bca",
  "ec6d20f7-dc81-4e64-98df-5b9b95abdb18",
  "305fc570-c11e-4a76-b57a-ad75c5d27996",
  "99d931f0-b2aa-4366-8a3f-bfc6d2e9286f",
  "3f053c2e-2cfe-44b2-8a35-912a8ddb1270",
  "839ce1d3-d96c-475c-9787-164560f8a106",
  "5c8c263b7a550e1fb6560c35",
  "50930efe-3e9b-4d89-8026-da840f9c906b",
  "d19cb41d-ac6c-4e95-848a-48f0fe9a9176",
  "d42158b9-c08d-4983-bade-5d5f478ce3bc",
  
    criteria_accounts = df.loc[df['CriteriaRules'] == account, 'CriteriaCloudAccounts'].unique()
    json_output.append({
        "CriteriaRules": account,
        "Unique CriteriaCloudAccounts": list(criteria_accounts)
    })

print(json.dumps(json_output, indent=2))
# Out:
# [
#   {
#     "CriteriaRules": "1e025bc1-ff97-409f-982d-39a810d5fa25",
#     "Unique CriteriaCloudAccounts": [
#       "128927813985",
#       "299975258897",
#       "130312249203",
#       "610375267642",
#       "34391304590",
#       "198052631016",
#       "947044032016",
#       "277141866027",
#       "703722312672",
#       "608515732360",
#       "712241193000",
#       "11275511485"
#     ]
#   },
#   {
#     "CriteriaRules": "bdc54b11-ece6-44b4-92a6-2bd3783fd0f2",
#     "Unique CriteriaCloudAccounts": [
#       "128927813985",
#       "299975258897",
#       "712241193000",
#       "703722312672",
#       "130312249203",
#       "947044032016",
#       "277141866027",
#       "11275511485",
#       "198052631016",
#       "608515732360",
#       "610375267642",
#       "34391304590",
#       "39042342264",
#       "435452409739"
#     ]
#   },
#   {
#     "CriteriaRules": "5d211f33-640f-47d5-860d-20b8c4205597",
#     "Unique CriteriaCloudAccounts": [
# ...

# %%
dl = pd.read_excel('WIZ - VMSS open & resolved rules.xlsx')

# %%
keys = dl.iloc[:, 2]  # First column
values = dl.iloc[:, 3]  # Second column

# Create a dictionary from the two columns
data_dict = dict(zip(keys, values))

# Convert the dictionary to JSON
json_data = json.dumps(data_dict, indent=4)

# Print the JSON data
print(json_data)
# Out:
# {
#     "High ": "AWS",
#     "NaN": NaN,
#     "Medium": "AWS",
#     "Low": "AWS"
# }

# %%
dl.iloc[4]
# Out:
# S.No                                                                            5.0
# Rule - VMSS                         Redshift cluster should require SSL connections
# Severity -VMSS                                                                High
# Provider                                                                        AWS
# Rule -WIZ                                                                       NaN
# Status in VMSS                                                                Open
# Duplicate from Supression sheet                                                 Yes
# VM Ware DocumentationLink                                                       NaN
# Name: 4, dtype: object

# %%
dh = pd.read_csv('WIZ-VMSS-RULES.csv')

# %%
keys = dh.iloc[:, 2]  # Third column
values = dh.iloc[:, 3]  # Fourth column

# Create a dictionary from the two columns
data_dict = dict(zip(keys, values))

# Convert the dictionary to JSON
json_data = json.dumps(data_dict, indent=4)

# Print the JSON data
print(json_data)
# Out:
# {
#     "ACM should not have a certificate with a wildcard domain": "ACM certificate domain name should not contain a wildcard",
#     "ACM Certificate Transparency logging should be enabled": "ACM certificate transparency logging should be enabled",
#     "ACM should not have certificates that are expired or expiring in the next 30 days": "ACM certificate expires within 30 days",
#     "Active Directory user should not have administrator access": "Not present in WIZ ",
#     "Subscription should not have associated custom owner role": "Not present in WIZ ",
#     "Auto Scaling group availability zone should match Elastic Load Balancer availability zone": NaN,
#     "Auto Scaling group should be configured with health checks": "Auto Scaling Group associated with a load balancer does not use load balancer health checks",
#     "Auto Scaling group should be configured with multiple availability zones": "Auto Scaling Group should cover multiple Availability Zones",
# ...
